# %%
import numpy as np
import pandas as pd

# %%
final = pd.read_csv('/content/data_audio_new_test.csv')

# %%
import csv
data1 = '/content/test_sent_emo.csv'
with open(data1, 'r') as f:
  reader = csv.reader(f)
  yourlist = list(reader)
traininginplist = []
traininglabels = []
for a, b, c, d, e, f, g, h, i,j, k in yourlist:
  traininginplist.append(['dia'+f+'_utt'+g+'.mp3', e])
  traininglabels.append(d)

# %%
traininginplist = np.array(traininginplist)

# %%
traininginplist.shape
# Out:
# (2611, 2)

# %%
traininginplist[1][1]
# Out:
# 'positive'

# %%
di = {}
for i in traininginplist:
  di[i[0]] = i[1]

# %%
di['dia0_utt0.mp3']
# Out:
# 'positive'

# %%
final
# Out:
#            Unnamed: 0           0           1  ...       190       191       192
# 0       dia0_utt0.mp3 -352.847230  121.015248  ... -0.039448 -0.000242  0.002305
# 1       dia0_utt1.mp3 -342.173040   87.203097  ...  0.004915  0.002242  0.000521
# 2       dia0_utt2.mp3 -362.927491  112.528435  ... -0.029796 -0.003427 -0.017818
# 3     dia100_utt0.mp3 -298.204423   97.688888  ...  0.003161 -0.013062  0.004476
# 4     dia100_utt1.mp3 -357.434918   72.865840  ... -0.012440  0.002505  0.006744
# ...               ...         ...         ...  ...       ...       ...       ...
# 2605    dia9_utt5.mp3 -249.915286  105.889326  ...  0.039029  0.003868 -0.001122
# 2606    dia9_utt6.mp3 -300.760231   83.911091  ... -0.000921  0.004686  0.000051
# 2607    dia9_utt7.mp3 -314.119549   90.346533  ... -0.017121  0.004639  0.004249
# 2608    dia9_utt8.mp3 -313.879298  100.372585  ...  0.035376  0.002427 -0.004696
# 2609    dia9_utt9.mp3 -276.907816  104.985208  ...  0.023472 -0.000749  0.003976
#
# ...

# %%
a = final.iloc[:,0]

# %%
a = sorted(a)

# %%
a.index('dia0_utt0.mp3')
# Out:
# 0

# %%
lab = np.zeros(len(a))

# %%
a.index(traininginplist[1][0])
# Out:
# 0

# %%
traininginplist = np.delete(traininginplist, 0, 0)

# %%
traininginplist
# Out:
# array([['dia0_utt0.mp3', 'positive'],
#        ['dia0_utt1.mp3', 'negative'],
#        ['dia0_utt2.mp3', 'neutral'],
#        ...,
#        ['dia279_utt13.mp3', 'neutral'],
#        ['dia279_utt14.mp3', 'neutral'],
#        ['dia279_utt15.mp3', 'neutral']], dtype='<U34')

# %%
traininglabels = np.delete(traininglabels, 0, 0)

# %%
for i in traininginplist:
  print(i)
  ind = a.index(i[0])
  if i[1] == 'neutral':
    lab[ind] = 2
  elif i[1] =='negative':
    lab[ind] = 1
  elif i[1] == 'positive':
    lab[ind] = 0
# Out:
# ['dia0_utt0.mp3' 'positive']
# ['dia0_utt1.mp3' 'negative']
# ['dia0_utt2.mp3' 'neutral']
# ['dia1_utt0.mp3' 'neutral']
# ['dia1_utt1.mp3' 'positive']
# ['dia1_utt2.mp3' 'positive']
# ['dia1_utt3.mp3' 'positive']
# ['dia1_utt4.mp3' 'positive']
# ['dia1_utt5.mp3' 'positive']
# ['dia1_utt6.mp3' 'positive']
# ['dia1_utt7.mp3' 'positive']
# ['dia2_utt0.mp3' 'neutral']
# ['dia2_utt1.mp3' 'neutral']
# ['dia2_utt2.mp3' 'negative']
# ['dia2_utt3.mp3' 'negative']
# ['dia2_utt4.mp3' 'negative']
# ['dia2_utt5.mp3' 'negative']
# ['dia2_utt6.mp3' 'negative']
# ['dia2_utt7.mp3' 'positive']
# ['dia2_utt8.mp3' 'positive']
# ['dia2_utt9.mp3' 'neutral']
# ['dia2_utt10.mp3' 'neutral']
# ['dia3_utt0.mp3' 'neutral']
# ['dia3_utt1.mp3' 'negative']
# ['dia3_utt2.mp3' 'neutral']
# ['dia3_utt3.mp3' 'neutral']
# ['dia3_utt4.mp3' 'negative']
# ['dia3_utt5.mp3' 'negative']
# ['dia3_utt6.mp3' 'neutral']
# ['dia4_utt0.mp3' 'positive']
# ['dia4_utt1.mp3' 'neutral']
# ['dia4_utt2.mp3' 'positive']
# ...

# %%
combined = np.vstack((a, lab)).T

# %%
combined.shape
# Out:
# (2610, 2)

# %%
with open("maybe_3.csv", "w") as f:
    writer = csv.writer(f)
    writer.writerows(combined)

# %%
data1
# Out:
# '/content/test_sent_emo.csv'

# %%
data1[0]
# Out:
# '/'

# %%
text = pd.read_csv('/content/test_sent_emo.csv')

# %%
text
# Out:
#       Sr No.  ...       EndTime
# 0          1  ...  00:14:40,378
# 1          2  ...  00:14:47,385
# 2          3  ...  00:14:57,520
# 3         19  ...   0:10:46,146
# 4         20  ...   0:10:46,833
# ...      ...  ...           ...
# 2605    2760  ...  00:14:40,211
# 2606    2761  ...  00:14:43,840
# 2607    2762  ...  00:14:48,511
# 2608    2763  ...  00:14:52,390
# 2609    2764  ...  00:14:54,183
#
# [2610 rows x 11 columns]

# %%
name = []
for i in range(2610):
  name.append('dia'+str(text.iloc[i,5])+'_utt'+str(text.iloc[i,6])+'.mp3')

# %%
text['name'] = name

# %%
text
# Out:
#       Sr No.  ...              name
# 0          1  ...     dia0_utt0.mp3
# 1          2  ...     dia0_utt1.mp3
# 2          3  ...     dia0_utt2.mp3
# 3         19  ...     dia1_utt0.mp3
# 4         20  ...     dia1_utt1.mp3
# ...      ...  ...               ...
# 2605    2760  ...  dia279_utt11.mp3
# 2606    2761  ...  dia279_utt12.mp3
# 2607    2762  ...  dia279_utt13.mp3
# 2608    2763  ...  dia279_utt14.mp3
# 2609    2764  ...  dia279_utt15.mp3
#
# [2610 rows x 12 columns]

# %%
text['name'][1]
# Out:
# 'dia0_utt1.mp3'

# %%
inplist = []
for i in range (2610):
  inplist.append([text['name'][i], text['Utterance'][i]])

# %%
inplist
# Out:
# [['dia0_utt0.mp3',
#   'Why do all you\x92re coffee mugs have numbers on the bottom?'],
#  ['dia0_utt1.mp3',
#   'Oh. That\x92s so Monica can keep track. That way if one on them is missing, she can be like, \x91Where\x92s number 27?!\x92'],
#  ['dia0_utt2.mp3', "Y'know what?"],
#  ['dia1_utt0.mp3', 'Come on, Lydia, you can do it.'],
#  ['dia1_utt1.mp3', 'Push!'],
#  ['dia1_utt2.mp3', "Push 'em out, push 'em out, harder, harder."],
#  ['dia1_utt3.mp3', "Push 'em out, push 'em out, way out!"],
#  ['dia1_utt4.mp3', "Let's get that ball and really move, hey, hey, ho, ho."],
#  ['dia1_utt5.mp3', "Let's\x97  I was just\x97yeah, right."],
#  ['dia1_utt6.mp3', 'Push!'],
#  ['dia1_utt7.mp3', 'Push!'],
#  ['dia2_utt0.mp3', 'Okay.'],
#  ['dia2_utt1.mp3', "Ross, didn't you say that there was an elevator in here?"],
#  ['dia2_utt2.mp3', "Uhh, yes I did but there isn't. Okay, here we go."],
#  ['dia2_utt3.mp3', 'Okay, go left. Left! Left!'],
# ...

# %%
withtext = np.zeros(len(inplist))
for i in inplist:
  print(i)
  ind = a.index(i[0])
  withtext[ind] = i[1]
# Out:
# ['dia0_utt0.mp3', 'Why do all you\x92re coffee mugs have numbers on the bottom?']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-120-ae39e54e9210> in <module>()
#       3   print(i)
#       4   ind = a.index(i[0])
# ----> 5   withtext[ind] = i[1]
#
# ValueError: could not convert string to float: 'Why do all you\x92re coffee mugs have numbers on the bottom?'

# %%
inplistnew = sorted(inplist, key = lambda x : x[0])

# %%
inplistnew
# Out:
# [['dia0_utt0.mp3',
#   'Why do all you\x92re coffee mugs have numbers on the bottom?'],
#  ['dia0_utt1.mp3',
#   'Oh. That\x92s so Monica can keep track. That way if one on them is missing, she can be like, \x91Where\x92s number 27?!\x92'],
#  ['dia0_utt2.mp3', "Y'know what?"],
#  ['dia100_utt0.mp3', 'Me taking care of you is no problem, huh?'],
#  ['dia100_utt1.mp3', 'You guys feel safe.'],
#  ['dia100_utt10.mp3', 'I broke it.'],
#  ['dia100_utt11.mp3', 'All right.'],
#  ['dia100_utt12.mp3', 'Well, that\x92s just the way that goes.'],
#  ['dia100_utt13.mp3', 'Okay, good.'],
#  ['dia100_utt14.mp3', 'Why are there only two of you?'],
#  ['dia100_utt15.mp3', 'Where is Leslie?'],
#  ['dia100_utt16.mp3', 'Well, you can\x92t answer.'],
#  ['dia100_utt17.mp3', 'Leslie?'],
#  ['dia100_utt18.mp3', 'Where are you Leslie?'],
#  ['dia100_utt19.mp3', 'Leslie, now would be a'],
#  ['dia100_utt2.mp3', 'Right?'],
#  ['dia100_utt3.mp3',
# ...

# %%
print(len(inplistnew))
# Out:
# 2610

# %%
print(len(combined))
# Out:
# 2610

# %%
for i in range (2610):
  if combined[i][0] != inplistnew[i][0]:
    print('com:', combined[i][0], 'in', inplistnew[i][0])

# %%
import pandas as pd

combined = pd.read_csv('maybe_3.csv', header=None)

# %%
for i in range (2610):
  if final.iloc[i,0] != inplistnew[i][0]:
    print('com:', final.iloc[i,0], 'in', inplistnew[i][0])

# %%
# Out:
#                         dia0_utt0.mp3  2
# 0                       dia0_utt1.mp3  6
# 1                       dia0_utt2.mp3  0
# 2                     dia100_utt0.mp3  0
# 3                     dia100_utt1.mp3  0
# 4                    dia100_utt10.mp3  1
# ...                               ... ..
# 2739  final_videos_testdia97_utt8.mp3  0
# 2740  final_videos_testdia98_utt3.mp3  0
# 2741  final_videos_testdia98_utt6.mp3  0
# 2742  final_videos_testdia98_utt8.mp3  0
# 2743   final_videos_testdia9_utt3.mp3  0
#
# [2744 rows x 2 columns]

# %%
for i in range(10):
  print(combined.iloc[i,0])
# Out:
# dia0_utt0.mp3
# dia0_utt1.mp3
# dia0_utt2.mp3
# dia100_utt0.mp3
# dia100_utt1.mp3
# dia100_utt10.mp3
# dia100_utt11.mp3
# dia100_utt12.mp3
# dia100_utt13.mp3
# dia100_utt14.mp3

# %%
len(final.iloc[:,0])
# Out:
# 2610

# %%
len(inplistnew)
# Out:
# 2610

# %%
inplistnew[:][1]
# Out:
# ['dia0_utt1.mp3',
#  'Oh. That\x92s so Monica can keep track. That way if one on them is missing, she can be like, \x91Where\x92s number 27?!\x92']

# %%
text = []
for i in inplistnew:
  text.append(i[1])

# %%
final['text'] = text

# %%
final
# Out:
#            Unnamed: 0  ...                                               text
# 0       dia0_utt0.mp3  ...  Why do all youre coffee mugs have numbers on ...
# 1       dia0_utt1.mp3  ...  Oh. Thats so Monica can keep track. That way ...
# 2       dia0_utt2.mp3  ...                                       Y'know what?
# 3     dia100_utt0.mp3  ...          Me taking care of you is no problem, huh?
# 4     dia100_utt1.mp3  ...                                You guys feel safe.
# ...               ...  ...                                                ...
# 2605    dia9_utt5.mp3  ...  Hey buddy, do you think I can borrow your unif...
# 2606    dia9_utt6.mp3  ...                                         Excuse me?
# 2607    dia9_utt7.mp3  ...                Joey! Hes working!  You would look
# 2608    dia9_utt8.mp3  ...                                 Oh, how bad is it?
# 2609    dia9_utt9.mp3  ...  Oh, its bad. Its really bad. The only thing ...
#
# [2610 rows x 195 columns]

# %%
final.to_csv('testing_data.csv')
